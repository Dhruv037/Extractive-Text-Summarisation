# %%
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt
# from sklearn import datasets
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.manifold import TSNE
from sklearn import preprocessing
import seaborn as sn
import numpy as np 
import pickle

# %%
X_train=pd.read_excel("X_train.xlsx")
y_train=pd.read_excel("y_train.xlsx")

X_test=pd.read_excel("X_test.xlsx")
y_test=pd.read_excel("y_test.xlsx")

# %%
# model_tSNE = TSNE(n_components=2, random_state=0)
# tsne_data = model_tSNE.fit_transform(X_train)

# %%
scaler = preprocessing.MinMaxScaler()
print(scaler.fit(tsne_data))
x_train = scaler.transform(tsne_data)

# X_test=scaler.transform(X_test)

y_train=np.array(y_train)
y_test=np.array(y_test)

x_train=x_train**100
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
wei=model.coef_
print(wei)
# Out:
# [[-3.10575618  0.71366113]]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:752: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
plot_decision_regions(x_train, y_train.reshape(x_train.shape[0],), clf=model, legend=2,markers='___')

# Adding axes annotations
# plt.xlabel('sepal length [cm]')
# plt.ylabel('petal length [cm]')
plt.title('LR on Data')
plt.show()

# %%
y_train=np.array(y_train)
plot_data=np.concatenate((x_train, y_train), axis=1)
plot_df = pd.DataFrame(data=plot_data, columns=("Dim_1", "Dim_2", "Label"))
sn.FacetGrid(plot_df, hue="Label", size=5).map(plt.scatter, 'Dim_1', 'Dim_2').add_legend()
plt.show()
plt.plot(wei[0])

# %%
x_train.shape
# Out:
# (32615, 2)

# %%
y_train.shape
# Out:
# (32615, 1)

# %%
wei[0]
# Out:
# array([0.07456454, 0.28794483])
